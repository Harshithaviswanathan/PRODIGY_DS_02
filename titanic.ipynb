# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Loading the dataset
titanic = pd.read_csv('C:/Users/DELL/Downloads/Titanic-Dataset.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# checking for duplicated values
titanic.duplicated().sum()
# Out:
# 0

# %%
# checking for null values
nv = titanic.isnull().sum().sort_values(ascending=False)
nv = nv[nv>0]
nv
# Out:
# Cabin       687
# Age         177
# Embarked      2
# dtype: int64

# %%
# Since Cabin column has too many null values, hence dropping the cabin column
titanic.drop(['Cabin'], axis = 1, inplace=True)
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
nv = titanic.isnull().sum().sort_values(ascending=False)
nv = nv[nv>0]
nv
# Out:
# Cabin       687
# Embarked      2
# dtype: int64

# %%
titanic_df.dropna(subset=['Embarked'], inplace=True)

# %%
#Distribution of passengers by class
sns.countplot(x='Pclass', data=titanic)
plt.title('Passenger Class Distribution')
plt.show()

# %%
#Relationship between survival and passenger class
sns.countplot(x='Pclass',hue='Survived',data=titanic)
plt.title('Survival by Passenger Class')
plt.show()

# %%
# Relationship between survival and age:
sns.histplot(x='Age', hue='Survived', data=titanic, bins=30)
plt.title('Survival by Age')
plt.show()

# %%
#Filtering out only numeric columns for the correlation plot
numeric_titanic = titanic.select_dtypes(include=[np.number])  # Keeps only numeric columns
correlation_matrix = numeric_titanic.corr()  # Compute correlation matrix on numeric columns only
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation')
plt.show()

# %%
# Gender distribution among passengers:
sns.countplot(x='Sex', data=titanic_df)
plt.title('Gender Distribution')
plt.show()

# %%
# Boxplot Distribution of fare by Passenger Class
sns.boxplot(x='Pclass', y='Fare', data=titanic_df)
plt.title('Fare Distribution by PClass')
plt.show()

# %%
# Survival Rate by Siblings/Spouses Aboard (SibSp)
sns.barplot(x='SibSp', y='Survived', data=titanic)
plt.title('Survival Rate by Siblings/Spouses Aboard')
plt.show()

# %%
# Age Distribution of Passengers Who Survived
sns.histplot(x='Age', data=titanic[titanic['Survived'] == 1], bins=30, kde=True, color='green')
plt.title('Age Distribution of Survived Passengers')
plt.show()

# %%
# Age Distribution of Passengers Who Did Not Survive
sns.histplot(x='Age', data=titanic_df[titanic_df['Survived'] == 0], bins=30, kde=True, color='red')
plt.title('Age Distribution of Non-Survived Passengers')
plt.show()

# %%
survived_passengers = titanic[titanic['Survived'] == 1]

# Create a count plot for survived passengers by passenger class
sns.countplot(x='Pclass', data=survived_passengers)
plt.title('Survived Passengers by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()

# %%
non_survived_passengers = titanic[titanic['Survived'] == 0]

# Create a count plot for survived passengers by passenger class
sns.countplot(x='Pclass', data=non_survived_passengers)
plt.title('Non-Survived Passengers by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()

# %%
# Survival Rate by Siblings/Spouses Aboard (SibSp)
sns.barplot(x='SibSp', y='Survived', data=titanic_df)
plt.title('Survival Rate by Siblings/Spouses Aboard')
plt.show()
